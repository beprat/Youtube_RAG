# %% [markdown]
# ## Installing Libraries

# %%
from youtube_transcript_api import YouTubeTranscriptApi,TranscriptsDisabled,NoTranscriptFound
from langchain_openai import ChatOpenAI,OpenAIEmbeddings
from langchain_core.prompts import PromptTemplate
from langchain_community.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter

from langchain_core.runnables import RunnableParallel,RunnablePassthrough,RunnableLambda
from langchain_core.output_parsers import StrOutputParser

# %% [markdown]
# ## i) Indexing

# %% [markdown]
# #### Step 1: Document Ingestion

# %%
video_id = "lTCzIDITaac"

try:
    # Create an instance of the API
    api = YouTubeTranscriptApi()

    # Fetch transcript using the instance method
    transcript_list = api.fetch(video_id)

    # Use attribute access (.text) instead of dictionary access (["text"])
    transcript = " ".join(chunk.text for chunk in transcript_list)
    print(transcript)

except TranscriptsDisabled:
    print("No captions available for this video.")
except NoTranscriptFound:
    print("No transcript found for this video.")
except Exception as e:
    print(f"Unexpected error: {e}")
print(transcript_list)
print(len(transcript_list))
print(type(transcript_list))
# Out:
# Let's [Music] go. [Music] For me, what does capitalism mean and what is the difference between capitalism and other forms? For me, capitalism is about giving people as much economic freedom as possible. Will our visas get canceled if we say why Americans are unhappy? I hope not. I'm not sure we've gone that bad as yet in America. Is there a line? I think Bitcoin is here to stay. Crypto is here to stay. This has lasted long enough. It's getting mainstream. You think so? Yeah. Whether it's banks or asset management firms who told you 5 years ago we'll never touch this thing. Have you got an allocation? [Music] Hi Ruch, thank you for coming. Uh, you've been on this table before. You've had lunch here before. So, I hope you feel slightly more comfortable than you might in a new place altogether. Yeah, I think that's uh fair. I mean, in terms of although the approach to the apartment is uh a bit of a project, but otherwise I feel has something changed uh in what way? Approach to the apartment? No, no. I just think that even last time because of the fact that this is a big complex here, right? So in terms of the fact that getting the specific B2 location in terms of the coordinates. No, I thought because of the Ganesha thing maybe it was fine today. No traffic. No, I mean it was pretty good. I mean as you know that like in Bombay everyone's raving about it but I see the effects is coastal roads made the biggest difference to our life. Yeah. Yeah. When you stay in Bombay where is home? Um at the Oroy. Okay. I still stay there in South Bombay. uh because I grew up here and so uh my father was in the Navy so we were in Navy Naga and then when I started my first job uh at Morgan Stanley I used to stay at Kuff Parade and so even though uh the center has moved much more towards Bandra uh BKC Bandra but uh somehow I still feel more rooted uh when I'm in that part of town maybe we can start there actually I have never asked you the origin story. How did you begin? Where were you born? I know you just said your dad was in the Navy, but what else? So, because of that, what happened was that we had a very nomadic existence, which is that every 2 years, my father would be transferred and because he'd be transferred, we would go along wherever he went. So, I was born in uh Wellington coming up uh in terms of I was speaking with my uh you know, with our friend Nilkini who was like telling me about how they spend a lot of time there now. Yeah. and u I need to go back and and revisit Kunor. So Nandan, Kiran, Ganjali, Prejour. Yeah. Uh and Nandan's house actually is the place where who's the guy who came up with the Turing test. Was it Alan Terring or something like that? Yeah. Yeah. His parents lived in Nandan's house in Kor. Yeah. Yeah. And they actually go there a lot. Nandan and Kiran and all they keep sharing stories about the Kunor Club. Yes. So me and Kiran live in the same apartment complex in Bangalore. Yes. And me, Nandan and Kiran, we all tend to catch up once every month or once every two months. It's like a Bangalore group. Yeah. I know. So like it's become a complete outpost for the Mangalore Club. Uh but so I was born there. There's a military kind of town there called Wellington. which is right uh next to Koro. It's it's part of Kunor for practical purposes. And so my father was posted there and I was born there. I don't have much memory of obviously when I was born out of memory but then he got transferred again there uh in the defense college uh when I was four and 5 years old. So I've got some memories of that uh growing up there going to the Willington club uh seeing him play golf and uh like those were the days. So then as I said every 2 years we shifted so I had a nomadic existence and so very difficult to make friends right because you you were always the sort of outsider in the in the in the school. Yeah. So as I said my father was uh also transferred to Singapore where he was the defense uh adviser uh in the Indian high comm ...
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text="Let's", start=0.0, duration=3.0), FetchedTranscriptSnippet(text='[Music]', start=3.99, duration=21.06), FetchedTranscriptSnippet(text='go.', start=22.08, duration=11.719), FetchedTranscriptSnippet(text='[Music]', start=25.05, duration=8.749), FetchedTranscriptSnippet(text='For me, what does capitalism mean and', start=34.64, duration=3.12), FetchedTranscriptSnippet(text='what is the difference between', start=36.64, duration=3.12), FetchedTranscriptSnippet(text='capitalism and other forms? For me,', start=37.76, duration=3.6), FetchedTranscriptSnippet(text='capitalism is about giving people as', start=39.76, duration=5.72), FetchedTranscriptSnippet(text='much economic freedom as possible.', start=41.36, duration=4.12), FetchedTranscriptSnippet(text='Will our visas get canceled if we say', start=48.8, duration=4.8), FetchedTranscriptSnippet(text='why Americans are unhappy?', start=50.64, duration=4.8), FetchedTranscriptSnippet(text="I hope not. I'm not sure we've gone that", start=53.6, duration=3.279), FetchedTranscriptSnippet(text='bad as yet in America.', start=55.44, duration=4.0), FetchedTranscriptSnippet(text='Is there a line?', start=56.879, duration=4.241), FetchedTranscriptSnippet(text='I think Bitcoin is here to stay. Crypto', start=59.44, duration=3.119), FetchedTranscriptSnippet(text='is here to stay. This has lasted long', start=61.12, duration=3.439), FetchedTranscriptSnippet(text="enough. It's getting mainstream.", start=62.559, duration=2.64), FetchedTranscriptSnippet(text='You think so?', start=64.559, duration=2.801), FetchedTranscriptSnippet(text="Yeah. Whether it's banks or asset", start=65.199, duration=3.6), FetchedTranscriptSnippet(text='management firms who told you 5 years', start=67.36, duration=2.96), FetchedTranscriptSnippet(text="ago we'll never touch this thing.", start=68.799, duration=5.161), FetchedTranscriptSnippet(text='Have you got an allocation?', start=70.32, duration=3.64), FetchedTranscriptSnippet(text='[Music]', start=75.85, duration=3.39), FetchedTranscriptSnippet(text='Hi Ruch, thank you for coming. Uh,', start=86.799, duration=5.441), FetchedTranscriptSnippet(text="you've been on this table before. You've", start=90.08, duration=3.84), FetchedTranscriptSnippet(text='had lunch here before.', start=92.24, duration=4.559), FetchedTranscriptSnippet(text='So, I hope you feel slightly more', start=93.92, duration=4.559), FetchedTranscriptSnippet(text='comfortable than you might in a new', start=96.799, duration=2.96), FetchedTranscriptSnippet(text='place altogether.', start=98.479, duration=3.921), FetchedTranscriptSnippet(text="Yeah, I think that's uh fair. I mean, in", start=99.759, duration=4.961), FetchedTranscriptSnippet(text='terms of although the approach to the', start=102.4, duration=4.48), FetchedTranscriptSnippet(text='apartment is uh a bit of a project, but', start=104.72, duration=3.28), FetchedTranscriptSnippet(text='otherwise I feel', start=106.88, duration=2.64), FetchedTranscriptSnippet(text='has something changed', start=108.0, duration=2.56), FetchedTranscriptSnippet(text='uh in what way?', start=109.52, duration=1.84), FetchedTranscriptSnippet(text='Approach to the apartment?', start=110.56, duration=2.32), FetchedTranscriptSnippet(text='No, no. I just think that even last time', start=111.36, duration=3.6), FetchedTranscriptSnippet(text='because of the fact that this is a big', start=112.88, duration=3.76), FetchedTranscriptSnippet(text='complex here, right? So in terms of the', start=114.96, duration=3.28), FetchedTranscriptSnippet(text='fact that getting the specific B2', start=116.64, duration=2.56), FetchedTranscriptSnippet(text='location', start=118.24, duration=1.919), FetchedTranscriptSnippet(text='in terms of the coordinates.', start=119.2, duration=2.4), FetchedTranscriptSnippet(text='No, I thought because of the Ganesha', start=120.159, duration=3.201), FetchedTranscriptSnippet(text='thing maybe it was ...
# 5503
# <class 'youtube_transcript_api._transcripts.FetchedTranscript'>

# %% [markdown]
# #### Step 2 : Text Splitting

# %%
splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
chunks=splitter.create_documents([transcript])
print(chunks[0])
print(type(chunks[0]))
print(type(chunks))
print(len(chunks))
# Out:
# page_content='Let's [Music] go. [Music] For me, what does capitalism mean and what is the difference between capitalism and other forms? For me, capitalism is about giving people as much economic freedom as possible. Will our visas get canceled if we say why Americans are unhappy? I hope not. I'm not sure we've gone that bad as yet in America. Is there a line? I think Bitcoin is here to stay. Crypto is here to stay. This has lasted long enough. It's getting mainstream. You think so? Yeah. Whether it's banks or asset management firms who told you 5 years ago we'll never touch this thing. Have you got an allocation? [Music] Hi Ruch, thank you for coming. Uh, you've been on this table before. You've had lunch here before. So, I hope you feel slightly more comfortable than you might in a new place altogether. Yeah, I think that's uh fair. I mean, in terms of although the approach to the apartment is uh a bit of a project, but otherwise I feel has something changed uh in what way? Approach to the'
# <class 'langchain_core.documents.base.Document'>
# <class 'list'>
# 229

# %% [markdown]
# #### Step 3 & 4: Embedding Generation and Storing in Vector Store

# %%
embeddings=OpenAIEmbeddings()
vector_store=FAISS.from_documents(chunks,embeddings)

# %%
vector_store.index_to_docstore_id
# Out:
# {0: '866cc4ad-c2e0-4b08-8a3c-47767e3b9eb5',
#  1: '2cf707fc-ce29-4741-9545-c614f55571e1',
#  2: '7be12496-101f-4993-a116-51c3f1bd5558',
#  3: '759dc305-8438-4dba-bc8a-7d16b7e829fe',
#  4: '1b725efa-0424-4de1-bf13-14dc5f82c054',
#  5: '903712be-72ae-4482-a9cc-b28f07ae2a4e',
#  6: '2bb81e2e-3cd1-4d97-b7e6-c6837c018fac',
#  7: '625ef0b3-6f51-4633-8ce0-ddf3b282df8a',
#  8: 'e7a6fec1-a24a-46c9-b553-ff85b7cc8c23',
#  9: 'cd52e244-3014-4351-a5eb-96d84453592b',
#  10: '34a330f4-efcf-4501-9888-5dc9648135e9',
#  11: '384825c1-15f2-4015-a035-2b16ebadb003',
#  12: 'c0c89abf-538e-41b3-92b4-4fdd9b635295',
#  13: '934befe2-dbc7-4563-890a-f4198c62dea0',
#  106: '2612b00e-4a46-4f99-807c-66e4dbab7c70',
#  107: 'fb5de06c-02e1-495b-812f-862f71df8816',
#  108: '73f33ead-dd3c-4297-8633-edb19a71bf31',
#  109: '36a67733-c164-430e-90bf-c36a0480728f',
#  110: 'c8dd834a-e47d-462b-8dd8-30ab4ff45545',
#  111: '42ec8d1d-1132-4921-8827-bb7a22fca353',
#  112: '693f9bdf-590c-48f1-b71d-aaf5d2e37495',
#  113: 'c6436c74-0799-42ad-9f7d-d5ec8bd6c537',
#  114: '60c7b961-630f-4bbf-ac6a-0733eeab674e',
#  115: 'cf7530b3-616f-48f1-a650-b8ba99d0b595',
#  116: '33cdbd89-da47-4027-8156-75a583a0b1ab',
#  117: '609df0ff-e845-4443-bee0-4e33e3bb9bd7',
#  118: '57276a28-c763-442f-9c26-50148da0cd4b',
#  119: '84edf326-dba7-4fb0-92b4-906083f0e0e4',
#  120: '95d6ac4f-7178-4ed1-bf96-2c9816faf5d1',
#  121: '252f918f-c291-4408-874a-7d09f6ef6032',
#  122: '0611b7c6-973d-4814-8df9-6d9b1fbebd3a',
#  123: 'e451b02d-db88-41df-bf7a-aa573d655959',
#  124: 'f2c3329f-7c85-422a-aad5-36f5609b69d4',
#  125: '49c53fe6-4f0a-44c1-8dd3-323b757f2126',
#  126: '6ffce288-cf89-4907-a59a-051f3eeea0ba',
#  127: 'c70b3ea7-be0c-487c-b35f-f60815b3de88',
#  128: '7187b90e-a7b7-4482-9ddf-432ba82602f9',
#  129: '08e4184d-722d-4d75-a6cb-d4ffa9190160',
#  130: 'b1e69122-8c97-4db8-9127-6b46717f13dd',
#  131: '408037b1-3c76-494f-940c-6c432ed94b3a',
#  132: '725eb720-344f-4c00-b639-ceebf5b93c98',
#  133: '125b0690-9ec4-4e1c-93db-3322cafc0a26',
#  134: 'bf5d433c-fbf8-4d5b-bea2-d8921bd70e90',
#  135: 'e9a21333-f003-4b8b-bb44-4fdcf51f57e7',
#  136: '45699322-1067-4a97-9c1c-0f965de4e5cc',
#  137: 'fc5ee39f-af51-452f-9609-97915ae24460',
#  138: '45d01641-2996-4dd5-89e9-972de2507953',
#  139: 'bbc1a750-898e-4939-9d3f-c968ea1807cd',
#  140: '2857e662-dd4c-425b-b081-ec4726f05ed3',
#  141: 'b46c61eb-f368-4dd4-8a09-3a2f0f92ed11',
#  142: '2fc25e24-73a0-4d08-95d5-08469dd795d1',
#  143: 'fd504882-ad84-4484-9d46-e998a9f0d646',
#  144: '12b1e066-0089-4a1d-ab40-42ad7220dfbc',
#  145: '6e7e55d8-14df-4035-8779-85396b2d5ab5',
#  146: '8a293a4b-2498-4a9e-9a8b-16b911f9cd66',
#  147: '38e5304a-f2be-420d-97ed-f977084afb97',
#  148: '19d3353a-ef6f-43c2-af59-79a40a608286',
#  149: '28092ce0-1202-4618-9838-0309d0cdfc4c',
#  150: '33937b1f-80da-49cb-b1b2-947f8fdf56d8',
#  151: 'b91223f1-f673-4ad2-8399-c887bfc70482',
#  198: '7743a061-78be-4835-aa00-baf468565d91',
#  199: 'a51aa3c2-6602-4d74-9e7a-1a8225515456',
#  200: 'cdff2cd7-4931-4472-8989-553696edb9e4',
#  201: '0bf854e6-d4cb-4812-bd83-d38efa5540ef',
#  202: 'a51b2a1a-9293-4c78-98d5-563bf72d6ef2',
#  203: 'fc8f8c8e-fa25-4d46-8c3e-433eb565f1dd',
#  204: '3f07c79e-8082-4cdd-bc2f-181ba69926f9',
#  205: '1653815e-605d-4e98-bd07-b414b879495a',
#  206: '5b7cc95a-6ab3-4cdf-9617-b28df44b71e3',
#  207: 'd9c40ae0-25a4-4e88-bf46-f725f5de8471',
#  208: 'c43d9b7c-ab28-4536-9c42-4ac573081d64',
#  209: '7b63e4ee-5588-4b9b-9c1e-a050c34b6606',
#  210: '1bdbf170-c273-4afb-996e-99853072d244',
#  211: '338a9701-260d-4e56-aecc-29cb6e251db1',
#  212: 'bc56c512-a009-4391-8292-31c6315b5d1c',
#  213: '773bfd39-658e-4f7d-a7f8-7404190eae56',
#  214: 'b9ed25ec-d66d-4e2f-b18d-95a215dcaca9',
#  215: '03fac750-6901-4b40-8872-1072db274515',
#  216: 'cd790dea-4215-4992-826a-dffb75c06a31',
#  217: '01c04c84-9a2e-4a09-b830-7c5b84ed20e9',
#  218: 'f888cc11-76f2-4775-8e5f-1d2944a6ce6c',
#  219: '7ddfb4a4-9ae2-463e-b29e-8b764e0cfb98',
#  220: '3831735b-08a5-4276-9ff2-2988f1a80ebf',
#  221: '5ff5a698-23dd-4160-b3f4-05580c9601df',
#  222: 'e9441baa-ec14-428b-a9a9-a1d4d9020540',
#  223: '0fc0c100-6891-4af4-9ddc-7b3103d76f8d',
#  224: 'f7bc635b-ae42-4e1b-8db0-997537c30874',
#  225: 'd6234ac8-a328-4819-90a3-a40cde34ecb4',
#  226: '975fda2b-ac1a-464c-9cb6-cbd581bbaafe',
#  227: 'a0e874f3-a5f9-4cb0-bc97-a3f619e08d97',
#  228: '8ddd4690-5c78-4b54-9153-fb5f2c1710f1'}

# %% [markdown]
# ## ii) Retrieval

# %%
retriver=vector_store.as_retriever(search_type="similarity",search_kwargs={"k":4})  ## 4 similar vectors dhundke dega

# %%
retriver.invoke("china vs india")
# Out:
# [Document(id='2bc19dbe-5c3b-467b-97d6-f1d427579394', metadata={}, page_content="remember that in 2019 in even in places like Hjao you room service was actually being done by robots. This is huge advances in China. So technology is its edge and even on the AI front the only other country in the world today which can do AI of any meaningful scale is China. No European country or any emerging market can. So I'd say that China in terms of so the two big negatives in China too much debt and demographics are all negative now in China is India going the same way demographic wise yeah but we are far far sort of you know our population is not shrinking in our lifetimes not up until 2100 they say yeah so as I said like in our lifetimes and you know beyond a point that's is too far off so for the next few years yes our demographic our population growth also has slowed down but it's no way close to sort of you know being a drag on growth or something. In China's case it is and they have too much debt. In fact, today China's debt today is uh like consumer debt or other debt"),
#  Document(id='234484de-f9da-41a7-a36d-234ae351bf90', metadata={}, page_content="Money is still coming in. But I think when we look back in history, we will look back at that as a very important turning point. Another thing that I'm no expert at geopolitics but the US seems to negotiate better with people who negotiate with them like them like you've seen in the example of China. Yeah. So when PM Modi our honorable prime minister is playing hard ball with him and this new alliance of India, China, Russia. Yeah. What do you think is the future of that? You know it's so hard to make these u projections because remember how things have changed right which is the fact that when Trump won the election uh the second time the first term there was a lot of euphoria in India and Russia uh and Russia you can argue but especially in India I'm talking about India right that that uh Trump is you know like going to be much more uh like us like friendly and stuff like that and there was still a lot of hostility towards China. In fact, even as recently as uh after uh operation"),
#  Document(id='f9ed7427-72a3-4e9c-b958-70ab1be62490', metadata={}, page_content="that in the world historically. I don't know of any such country. So what did China do different? As I said that what China did was that it that it built this massive infrastructure so that it became very easy to like ship goods out of the country and also in terms of its people it just told people that you go and find a job wherever you want we are not the state is not going to in terms of give you support to remain on the farm right so you go find you know whatever you want now in India's case the politics is very different here uh in fact where you know like now Now it's become a routine thing that this thing like mandrega and stuff right which is what the dural employment guarantee scheme uh now the way that it functions is and you can argue that it's very you know that it's maybe the right thing for India to do given its democratic setup and the polity here but there like in China's case didn't have any mrega and things they just told their people that if you can't make enough"),
#  Document(id='0078d7c3-ed93-4b56-9dc7-872b1bd503c4', metadata={}, page_content="know like some domestic version of Twitter or something a few who I was invested in that it shut down. Yeah. So that's the point. We've tried it. We have not been able to create it as yet. The one thing America does a stellar job at is selling patriotism. I don't know how they do it, but to see a flag outside every other house, to talk about this American dream and all of that, you see it, it's like it's permeated all parts of society. I think India is on that path. Mhm. Where everybody's getting more patriotic. Like I'm a big champion of buy Indian brands only. Like I'll buy shirts from 111. and I'll buy my chuples from some brand here. I feel like we're on that journey. I don't know when that line is crossed, but I feel like that's the that's the time when this when they have something to lose and bargaining becomes more fair. Well, that's what's happening with China today. Yeah. Right. I mean so in terms of the fact that because China sort of has the rare earths and stuff but")]

# %% [markdown]
# ## iii) Augmentation

# %%
prompt=PromptTemplate(
    template="""
    You are a helpful assistant.
    Answer ONLY from the provided tanscript content.
    If the context is insufficient,just say you dont know.

    Context:{context}

    Question:{question}
    """,
    input_variables=["context","question"],
)

# %%
question="What are we talking here?"
retrieved_docs=retriver.invoke(question)

# %% [markdown]
# ## iv) Generation

# %%
context_text="\n\n".join(docs.page_content for docs in retrieved_docs)
final_promt=prompt.format(context=context_text,question=question)

# %%
llm=ChatOpenAI()
answer=llm.invoke(final_promt)
print(answer.content)
# Out:
# Sorry, I do not have enough information to provide an accurate answer to your question.

# %% [markdown]
# ## Building Chains

# %%
def format_docs(retrieved_docs):
  context_text="\n\n".join(docs.page_content for docs in retrieved_docs)
  return context_text

# %%
parallel_chain=RunnableParallel({
    'context':retriver | RunnableLambda(format_docs),   ## Lamnbda  beacuse format_docs ko runnable banana hai
    'question':RunnablePassthrough()   ## Jo input mein mila uski ko dalna
})

# %%
parser=StrOutputParser()

# %%
main_chain=parallel_chain | prompt | llm | parser

# %%
main_chain.invoke("Who are the speakers, their names?")
# Out:
# 'The speakers mentioned in the provided transcript are Putin and Christine Lagard.'
